# %% [markdown]
# # Finding Heavy Traffic Indicators on I-94
#
# In this project we will be working with a data set containing data about westbound traffic on US Interstate Highway I-94. Our goal will be to analyze the data to determine which factors are indicators of heavy traffic on the highway.
#
# The data set was made available by John Hogue and can be downloaded from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Metro+Interstate+Traffic+Volume). The documentation for the data set explains that the data was collected at a station midway between Minneapolis and St. Paul MN, and data was only collected for westbound traffic.

# %% [markdown]
# ## Inital Data Exploration
#
# We will begin by reading in and examining our data set using Pandas:

# %%
import pandas as pd

traffic = pd.read_csv('Metro_Interstate_Traffic_Volume.csv')
traffic.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
traffic.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199    None  283.45      0.0      0.0          75        Clouds
# 48200    None  282.76      0.0      0.0          90        Clouds
# 48201    None  282.73      0.0      0.0          90  Thunderstorm
# 48202    None  282.09      0.0      0.0          90        Clouds
# 48203    None  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 48199           broken clouds  2018-09-30 19:00:00            3543
# 48200         overcast clouds  2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm  2018-09-30 21:00:00            2159
# 48202         overcast clouds  2018-09-30 22:00:00            1450
# 48203         overcast clouds  2018-09-30 23:00:00             954

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# Our data set has 48204 rows, each representing an hour of the day. The timeframe of the data set ranges from 2012-10-02 09:00:00 to 2018-09-30 23:00:00, a period of roughly six years. We can also see that our data set contains no null values.

# %% [markdown]
# ## Analyzing Traffic Volume
#
# Now that we have taken a quick look at the structure of our data set, we will take a closer look at the `traffic_volume` column. This column will be important to our analysis since we are concered with factors that my contribute to increasing traffic volume. To start, we will plot a histogram of this column using Matplotlib:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

traffic['traffic_volume'].plot.hist()
plt.show()

traffic['traffic_volume'].describe()
# Out:
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# The amount of cars per hour in our data set ranges from 0 to 7280. Our histogram shows us that there are a large number of values in the 0-1000 cars range and the stats tell us that about 25% of the time there are 1193 cars passing the station per hour on I-94. This likely corresponds to hours in the middle of the night when most people are sleeping or during hours when construction is taking place, limiting the amount of cars that can pass through at a time. The histogram also shows a large amout of values in the 4500-5000 range, and we can see that 25% of the time there are 4933 cars passing the station. This likley corresponds to rush hour traffic in the morning and evening hours.

# %% [markdown]
# ## Traffic Volume: Day vs. Night
#
# Building off the insights gained from our histogram above, we will now dig deeper into the difference in traffic volume during the day vs during the night. To do this, we will start by dividing our data set into day hours (7AM to 7PM) and night hours (7PM to 7AM):

# %%
traffic['date_time'] = pd.to_datetime(traffic['date_time'])
day = traffic[(traffic['date_time'].dt.hour >= 7) & (traffic['date_time'].dt.hour < 19)]
print(day.shape)
night = traffic[(traffic['date_time'].dt.hour >= 19) | (traffic['date_time'].dt.hour < 7)]
print(night.shape)
# Out:
# (23877, 9)
# (24327, 9)

# %% [markdown]
# There are some missing rows for the night time data, which can be attributed to rows in the data set that are missing entries. To better help us visualize the differences in traffic between day and night, we will plot histograms of both data sets:

# %%
plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
plt.hist(day['traffic_volume'])
plt.xlim(0, 8000)
plt.ylim(0, 8000)
plt.title('Traffic Volume: Day')
plt.ylabel('Frequency')
plt.xlabel('Traffic Volume')

plt.subplot(1, 2, 2)
plt.hist(night['traffic_volume'])
plt.xlim(0, 8000)
plt.ylim(0, 8000)
plt.title('Traffic Volume: Night')
plt.ylabel('Frequency')
plt.xlabel('Traffic Volume')

plt.show()

# %% [markdown]
# Our histograms clearly show us that traffic volume is much lighter during night time hours when compared to daytime hours, due to the obvious fact that most people are sleeping at night and not on the road. Since we are interested in determining indicators of heavy traffic, we will shift our focus to the day time hours.

# %% [markdown]
# ## Exploring Time Indicators
#
# One obvious indicator of traffic density is the time of day. For instance, we can reasonably expect traffic volume to increase during "rush hour", or the hours when the majority of people are commuting to or from work. To continue our analysis we will plot graphs to compare traffic density to different times such as month, day of the week, and time of day. We will start with examining how traffic density changes month to month:

# %%
day['month'] = day['date_time'].dt.month
by_month = day.groupby('month').mean()
by_month['traffic_volume'].plot.line()
plt.show()
# Out:
# <ipython-input-13-fe2551350c82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day['month'] = day['date_time'].dt.month

# %% [markdown]
# By plotting the month of the year against traffic density, we can see that there is dense traffic for most of the year, however there are two times when traffic denisty drops dramatically. One of these times is in the winter months from approximatly November to January. These months correspond to the holidays (Thanksgiving and Christmas in the US) where many people take off work which could contribute to the drop in commuter travel. The other drop is in the summer around the month of July. Again, this is a popular month for taking summmer vacation in the US, the drop in traffic density could be caused by people taking off work to vacation. Next we will plot the day of the week against traffic density:

# %%
day['dayofweek'] = day['date_time'].dt.dayofweek
by_dayofweek = day.groupby('dayofweek').mean()
by_dayofweek['traffic_volume'].plot.line()
plt.show()
# Out:
# <ipython-input-14-4491a4ad814c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day['dayofweek'] = day['date_time'].dt.dayofweek

# %% [markdown]
# The plot of day of the week vs traffic density matches what we would expect. Traffic density is high during the work week (Monday to Friday) and then drops dramatically on the weekend. This can be explained by the majority of weekly commuters having weekends off and therefore not driving on the road to work like they would be on weekdays. Finally, we will plot time of day vs traffic density. We will make two plots, one for weekdays and one for weekends, as weekend hours where less people are traveling will bring down the averages of the weekday hours:

# %%
day['hour'] = day['date_time'].dt.hour
bussiness_days = day.copy()[day['dayofweek'] <= 4] # 4 == Friday
weekend = day.copy()[day['dayofweek'] >= 5] # 5 == Saturday
by_hour_business = bussiness_days.groupby('hour').mean()
by_hour_weekend = weekend.groupby('hour').mean()

plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
by_hour_business['traffic_volume'].plot.line()
plt.ylim(1500, 7000)
plt.title('Weekday Traffic by Hour')

plt.subplot(1, 2, 2)
by_hour_weekend['traffic_volume'].plot.line()
plt.ylim(1500, 7000)
plt.title('Weekend Traffic by Hour')

plt.show()
# Out:
# <ipython-input-16-ce93c8d7e48f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day['hour'] = day['date_time'].dt.hour

# %% [markdown]
# Comparing the two line graphs we can see drastic differences. Weekday traffic is higher at all hours of the day when compared to weekend traffic and we can see two times of the day where traffic density spikes significantly, corresponding to rush hours when most people are commuting to or from work. For weekend traffic, we see a steady increase in traffic until about noon, where traffic levels off for the rest of the day.

# %% [markdown]
# ## Weather Indicators
#
# So far we have looked at several different traffic density indicators related to time, to close out our analysis we will look at another type of indicator: the weather. We will begin by looking up the correlation values of the numaric weather related columns of our data set with the `traffic_volume` column:

# %%
day.corr()['traffic_volume']
# Out:
# temp              0.128317
# rain_1h           0.003697
# snow_1h           0.001265
# clouds_all       -0.032932
# traffic_volume    1.000000
# month            -0.022337
# dayofweek        -0.416453
# hour              0.172704
# Name: traffic_volume, dtype: float64

# %% [markdown]
# We can see that temp, rain, and snow have positive correlations to traffic density while cloud cover has a negative correlation. Let's take a closer look at the temperature column, which has the strongest positive correlation to traffic density:

# %%
day.plot.scatter('traffic_volume', 'temp')
plt.ylim(200, 400)
plt.show()

# %% [markdown]
# The scatter plot shows us that temperture is not a good indicator of traffic density. We will continue our examination of weather data by looking at the `weather_main` and `weather_description` columns:

# %%
by_weather_main = day.groupby('weather_main').mean()
by_weather_main['traffic_volume'].plot.barh()
plt.show()

# %% [markdown]
# There are no main weather conditions that have traffic density values over 5000 cars, which makes it hard to draw conclusions from this data. Next wee will take a look at the `weather_description` column which takes a more granular approach to defining weather types:

# %%
by_weather_description = day.groupby('weather_description').mean()
by_weather_description['traffic_volume'].plot.barh(figsize=(10, 15))
plt.show()

# %% [markdown]
# We can now see that there are 3 weather classifications that have traffic densities of over 5000 cars: light rain and snow, proximity thunderstorm with drizzle, and shower snow. It is not very clear why these 3 weather patterns resulted in traffic densities over 5000, they all represent adverse weather but there are worse weather events in the column (such as very heavy rain or heavy snow) that do not have traffic densities over 5000. One possibility is that light rain and snow, proximity thunderstom with drizzle, and shower snow are weather events that are bad enough to slow down traffic, but not bad enough to keep people off the roads whereas the more severe weather events cause people to not want to drive in them so traffic density does not increase.

# %% [markdown]
# ## Conclusions
#
# In this project we examined a data set containing data on westbound traffic on I94 in Minnesota in order to determine indicators of heavy traffic density. Our analysis showed us that there were several time indicators that showed higher traffic density:
# - Weekdays (Monday-Friday)
# - Spring and Fall months (away from holidays and middle of summer)
# - Rush hours
#
# There were also three weather patterns that indicated heavier traffic:
# - light rain and snow
# - proximity thunderstorm with drizzle
# - shower snow
